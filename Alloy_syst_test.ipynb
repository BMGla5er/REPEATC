# %%
import Alloy_System_Class
from Alloy_System_Class import alloy_sys

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# from Alloy_System import alloy_sys, do_peform_single_axis_split, phase_distribution, composition_distribution, element_distribution
# from Alloy_System_with_suspension import alloy_sys, do_peform_single_axis_split, phase_distribution, composition_distribution, element_distribution

# %%
alsi10mg = alloy_sys("Al",{"Si":0.1,"Mg":0.0035},"T",range(300,1300,50),False,"TCAL9","W")
alsi10mg.do_perform_single_axis_split(T=298,threshold=0.0001)

# %%
alsi10mg.phase_distribution()

# %%
alsi10mg.element_distribution()

# %%
alsi10mg.composition_distribution()

# %%
als1phase_distribution(alsi10mg)

# %%
composition_distribution(alsi10mg)

# %%
element_distribution(alsi10mg)

# %%
alsi10mg.phases
# Out:
# [{'DIAMOND_A4#1': {'frac': 0.09446446528342674,
#    'Al': 1.0000000000000002e-12,
#    'Si': 0.999999999999,
#    'Mg': 0.0},
#   'FCC_A1#1': {'frac': 0.8996867276321949,
#    'Al': 0.9999998245344944,
#    'Si': 6.107487759061282e-08,
#    'Mg': 1.1439062793694514e-07},
#   'MG2SI_C1#1': {'frac': 0.00584880708437842,
#    'Al': 0.0,
#    'Si': 0.3333333333333333,
#    'Mg': 0.6666666666666666}},
#  {'DIAMOND_A4#1': {'frac': 0.09446424957617858,
#    'Al': 1.0000000000000002e-12,
#    'Si': 0.999999999999,
#    'Mg': 0.0},
#   'FCC_A1#1': {'frac': 0.8996886864608514,
#    'Al': 0.999997647304798,
#    'Si': 9.46656993654598e-07,
#    'Mg': 1.4060382084144205e-06},
#   'MG2SI_C1#1': {'frac': 0.005847063962969738,
#    'Al': 0.0,
#    'Si': 0.3333333333333333,
#    'Mg': 0.6666666666666666}},
#  {'DIAMOND_A4#1': {'frac': 0.09446196777972261,
#    'Al': 1.0000000000000002e-12,
#    'Si': 0.999999999999,
#    'Mg': 0.0},
#   'FCC_A1#1': {'frac': 0.8997015280677361,
#    'Al': 0.9999833741522788,
#    'Si': 7.395152841949915e-06,
#    'Mg': 9.230694879196074e-06},
#   'MG2SI_C1#1': {'frac': 0.00583650415254109,
#    'Al': 0.0,
#    'Si': 0.3333333333333333,
#    'Mg': 0.6666666666666666}},
#  {'DIAMOND_A4#1': {'frac': 0.09444949901344663,
#    'Al': 1e-12,
#    'Si': 0.999999999999,
#    'Mg': 0.0},
#   'FCC_A1#1': {'frac': 0.899755389193149,
#    'Al': 0.999923513182364,
#    'Si': 3.658733294243574e-05,
#    'Mg': 3.9899484693499785e-05},
#   'MG2SI_C1#1': {'frac': 0.0057951117934044935,
#    'Al': 0.0,
#    'Si': 0.3333333333333333,
#    'Mg': 0.6666666666666666}},
#  {'DIAMOND_A4#1': {'frac': 0.09440408219015645,
#    'Al': 1.220116478890201e-11,
#    'Si': 0.9999999999877989,
#    'Mg': 0.0},
#   'FCC_A1#1': {'frac': 0.8999207741355855,
#    'Al': 0.9997397500128403,
#    'Si': 0.00013148473825448322,
#    'Mg': 0.00012876524890514642},
#   'MG2SI_C1#1': {'frac': 0.005675143674258279,
#    'Al': 0.0,
#    'Si': 0.3333333333333333,
#    'Mg': 0.6666666666666666}},
#  {'DIAMOND_A4#1': {'frac': 0.09427861935933463,
#    'Al': 1.4511119195758313e-10,
#    'Si': 0.9999999998548889,
#    'Mg': 0.0},
#   'FCC_A1#1': {'frac': 0.9003264339006605,
#    'Al': 0.9992892976109281,
#    'Si': 0.000374517126428785,
#    'Mg': 0.0003361852626431734},
#   'MG2SI_C1#1': {'frac': 0.005394946740004774,
#    'Al': 0.0,
#    'Si': 0.3333333333333333,
#    'Mg': 0.6666666666666666}},
#  {'DIAMOND_A4#1': {'frac': 0.09399449481564799,
#    'Al': 1.1416719847573585e-09,
#    'Si': 0.999999998858328,
#    'Mg': 0.0},
#   'FCC_A1#1': {'frac': 0.901169380105808,
#    'Al': 0.9983545707621347,
#    'Si': 0.000896153610154518,
#    'Mg': 0.0007492756277107176},
#   'MG2SI_C1#1': {'frac': 0.004836125078544314,
#    'Al': 0.0,
#    'Si': 0.3333333333333333,
#    'Mg': 0.6666666666666666}},
#  {'DIAMOND_A4#1': {'frac': 0.09343946372401005,
#    'Al': 6.533741543452817e-09,
#    'Si': 0.9999999934662586,
#    'Mg': 0.0},
#   'FCC_A1#1': {'frac': 0.902715424662041,
#    'Al': 0.9966447283130667,
#    'Si': 0.0018754034366305558,
#    'Mg': 0.0014798682503028172},
#   'MG2SI_C1#1': {'frac': 0.003845111613949031,
#    'Al': 0.0,
#    'Si': 0.3333333333333333,
#    'Mg': 0.6666666666666666}},
#  {'DIAMOND_A4#1': {'frac': 0.09247073056498116,
#    'Al': 2.910426879679731e-08,
#    'Si': 0.9999999708957312,
#    'Mg': 0.0},
#   'FCC_A1#1': {'frac': 0.9052931715814901,
#    'Al': 0.9938068631444937,
#    'Si': 0.003532589077278157,
#    'Mg': 0.002660547778228082},
#   'MG2SI_C1#1': {'frac': 0.0022360978535287197,
#    'Al': 0.0,
#    'Si': 0.3333333333333333,
#    'Mg': 0.6666666666666666}},
#  {'DIAMOND_A4#1': {'frac': 0.09085466163808006,
#    'Al': 1.0604394129806686e-07,
#    'Si': 0.9999998939560587,
#    'Mg': 0.0},
#   'FCC_A1#1': {'frac': 0.9091453383619198,
#    'Al': 0.9895959668596823,
#    'Si': 0.00611505152856082,
#    'Mg': 0.004288981611756782}},
#  {'DIAMOND_A4#1': {'frac': 0.08743008116324946,
#    'Al': 3.2869205273857953e-07,
#    'Si': 0.9999996713079473,
#    'Mg': 0.0},
#   'FCC_A1#1': {'frac': 0.9125699188367505,
#    'Al': 0.9858823115450462,
#    'Si': 0.009844802007393603,
#    'Mg': 0.004272886447560211}},
#  {'FCC_A1#1': {'frac': 0.21343028287788618,
#    'Al': 0.9847504311508276,
#    'Si': 0.014394756138276423,
#    'Mg': 0.0008548127108960454},
#   'LIQUID#1': {'frac': 0.7865697171221135,
#    'Al': 0.8766050760318511,
#    'Si': 0.11866951357025857,
#    'Mg': 0.004725410397890343}},
#  {'LIQUID#1': {'frac': 0.9999999999999998,
#    'Al': 0.8996865697668237,
#    'Si': 0.09641412259452767,
#    'Mg': 0.0038993076386486716}},
#  {'LIQUID#1': {'frac': 0.9999999999999999,
#    'Al': 0.8996865697668236,
#    'Si': 0.09641412259452775,
#    'Mg': 0.003899307638648671}},
#  {'LIQUID#1': {'frac': 1.0000000000000002,
#    'Al': 0.8996865697668237,
#    'Si': 0.09641412259452763,
#    'Mg': 0.0038993076386486564}},
#  {'LIQUID#1': {'frac': 0.9999999999999999,
#    'Al': 0.8996865697668237,
#    'Si': 0.09641412259452774,
#    'Mg': 0.003899307638648669}},
#  {'LIQUID#1': {'frac': 1.0,
#    'Al': 0.8996865697668237,
#    'Si': 0.09641412259452771,
#    'Mg': 0.003899307638648668}},
#  {'LIQUID#1': {'frac': 0.9999999999999998,
#    'Al': 0.8996865697668237,
#    'Si': 0.09641412259452767,
#    'Mg': 0.0038993076386486664}},
#  {'LIQUID#1': {'frac': 1.0000000000000002,
#    'Al': 0.8996865697668237,
#    'Si': 0.09641412259452767,
#    'Mg': 0.003899307638648681}},
#  {'LIQUID#1': {'frac': 0.9999999999999997,
#    'Al': 0.8996865697668237,
#    'Si': 0.09641412259452771,
#    'Mg': 0.0038993076386486633}}]

# %% [markdown]
# ## Phase suspension test

# %%
user_database = False
#user_path = 'Jupyter/Al_jan05.TDB'
tc_database = "TCNI12"

dependent_element = "Fe"
composition = {"Ni": 0.535,
               "Cr": 0.1946,
               "Nb": 0.0531,
               "Al": 0.0031,
               "Ti": 0.01,
               "Co": 0.002,
               "Mo": 0.0299
               #"C": 0.00034
               #"O":  0.000574441
               }  # in weight fraction #
comp_metric = 'W' # W: weight fraction, X: mole fraction

param = 'T'
param_range = range(300,1300,100) #in Kelvin
Temp = 923.15 #kelvin  = 650 degree C

elements = list(composition.keys())
nelem = len(elements)
# suspending_phases = ['BCC_B2#1','SIGMA#1','NI3TA_D0A#1', 'C14_LAVES#1','M6C#1','R_PHASE#1']
suspending_phases = ['NI3TA_D0A#1', 'NI3TI_D024#1','P_PHASE#1']
excluded_keys = ["BCC_B2#1","BCC_B2#3", "FCC_L12#4"]

# %%
alloy = alloy_sys(dependent_element,composition,param, param_range ,user_database,tc_database,comp_metric,suspending_phases)

alloy.do_perform_single_axis_split(T=923.15,threshold=0.0001)
#do_peform_single_axis_split(alloy,T=923.15,threshold=0.001)

# %%
alloy.phase_distribution()
alloy.composition_distribution()
alloy.element_distribution()

# %%
a = alloy
phase_distribution(a)
element_distribution(a)
composition_distribution(a)

# %%
a = alloy
# phase_distribution(a,excluded=excluded_keys)
phase_distribution(a)
element_distribution(a,excluded=excluded_keys)
composition_distribution(a,excluded=excluded_keys)

# %% [markdown]
# ## business as usual

# %%
alsi10mg2 = alloy_sys("Al",{"Si":0.1,"Mg":0.0035,'Fe':0.00001},"W","Fe",np.linspace(0.00001,0.005,10),False,"TCAL9")
do_peform_single_axis_split(alsi10mg2,T=298,threshold=0.0001)

# %%
a = alsi10mg2
phase_distribution(a)
element_distribution(a)
composition_distribution(a)

# %%
inconel = alloy_sys("Fe",{"Ni": 0.5355,"Cr": 0.1946,"Nb":0.0531,"Al":0.0031,
               "Co":0.002,"Ti":0.01,"Mo":0.0299},"W","T",range(300,1300,100),False,"TCNI12")
do_peform_single_axis_split(inconel,T=298,threshold=0.0001)

# %%
a = inconel
phase_distribution(a)
element_distribution(a)
composition_distribution(a)
